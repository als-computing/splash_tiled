# %%
from tiled.client import from_uri
c = from_uri("https://tiled.computing.als.lbl.gov")

# %%
c.login()
# Out:
# Username:  dmcreynolds
#  ········
# Username or password not recognized. Retry, or press Enter to cancel.
#  ········
# Username or password not recognized. Retry, or press Enter to cancel.
#  ········

# %%
c['beamlines'].create_container('bl832')
# bl832 = c['beamlines/bl832']
# c['beamlines/bl832'].delete(recursive=True)
# list(bl832)
# Out:
# <Container {}>

# %%
from tiled.client.register import register

# %%
await register(bl832, "/global/beegfs/beamlines/bl832", overwrite=False)

# %%
list(c['beamlines/bl832'])
# Out:
# ['ec20250706_134728_Carbonfiber', 'rec20250706_134728_Carbonfiber']

# %%
bl832['rec20250706_134728_Carbonfiber.zarr']
# Out:
# Scheduled retry in 0.91 seconds due to HTTPStatusError("Server error '500 Internal Server Error' for url 'https://tiled.computing.als.lbl.gov/api/v1/metadata/beamlines/bl832/rec20250706_134728_Carbonfiber.zarr'\nFor more information, server admin can search server logs for correlation ID 88b22124809cf82d.") (attempt 1)
# Scheduled retry in 0.44 seconds due to HTTPStatusError("Server error '500 Internal Server Error' for url 'https://tiled.computing.als.lbl.gov/api/v1/metadata/beamlines/bl832/rec20250706_134728_Carbonfiber.zarr'\nFor more information, server admin can search server logs for correlation ID fa27205404483341.") (attempt 2)
# Scheduled retry in 0.59 seconds due to HTTPStatusError("Server error '500 Internal Server Error' for url 'https://tiled.computing.als.lbl.gov/api/v1/metadata/beamlines/bl832/rec20250706_134728_Carbonfiber.zarr'\nFor more information, server admin can search server logs for correlation ID ffab1c2ad67682ec.") (attempt 3)
# Scheduled retry in 1.7 seconds due to HTTPStatusError("Server error '500 Internal Server Error' for url 'https://tiled.computing.als.lbl.gov/api/v1/metadata/beamlines/bl832/rec20250706_134728_Carbonfiber.zarr'\nFor more information, server admin can search server logs for correlation ID a2143fa3bc31fd7c.") (attempt 4)
# Scheduled retry in 2.5 seconds due to HTTPStatusError("Server error '500 Internal Server Error' for url 'https://tiled.computing.als.lbl.gov/api/v1/metadata/beamlines/bl832/rec20250706_134728_Carbonfiber.zarr'\nFor more information, server admin can search server logs for correlation ID bb48131ebf649f5c.") (attempt 5)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[194], line 1
# ----> 1 bl832['rec20250706_134728_Carbonfiber.zarr']
#
# File ~/micromamba/envs/tiled/lib/python3.12/site-packages/tiled/client/container.py:347, in Container.__getitem__(self, keys, _ignore_inlined_contents)
#     345     params["include_data_sources"] = True
#     346 link = self_link + "".join(f"/{key}" for key in keys[i:])
# --> 347 for attempt in retry_context():
#     348     with attempt:
#     349         content = handle_error(
#     350             self.context.http_client.get(
#     351                 link,
#    (...)    357             )
#     358         ).json()
#
# File ~/micromamba/envs/tiled/lib/python3.12/site-packages/stamina/_core.py:525, in _RetryContextIterator.__iter__(self)
#     519     return
#     521 before_sleep = _make_before_sleep(
#     522     self._name, CONFIG, self._args, self._kw, self._cms_to_exit
#     523 )
# --> 525 for r in _t.Retrying(
#     526     before=self._exit_cms,
#     527     before_sleep=before_sleep,
#     528     **self._apply_maybe_test_mode_to_tenacity_kw(CONFIG.testing),
#     529 ):
#     530     yield Attempt(r, self._backoff_for_attempt_number)
#
# File ~/micromamba/envs/tiled/lib/python3.12/site-packages/tenacity/__init__.py:450, in BaseRetrying.__iter__(self)
#     448 elif isinstance(do, DoSleep):
#     449     retry_state.prepare_for_next_attempt()
# --> 450     self.sleep(do)
#     451 else:
#     452     break
#
# File ~/micromamba/envs/tiled/lib/python3.12/site-packages/tenacity/nap.py:31, in sleep(seconds)
#      25 def sleep(seconds: float) -> None:
#      26     """
#      27     Sleep strategy that delays execution for a given number of seconds.
#      28
#      29     This is the default strategy, and may be mocked out for unit testing.
#      30     """
# ---> 31     time.sleep(seconds)
#
# KeyboardInterrupt:

# %%
bl832
# Out:
# <Container {'scale2', 'scale0'}>
