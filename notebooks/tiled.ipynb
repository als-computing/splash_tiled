# %%
from tiled.client import from_uri
c = from_uri("https://tiled.computing.als.lbl.gov")

# %%
c.create_container("bl531")
# Out:
# <Container {}>

# %%
c
# Out:
# <Container {'bl531'}>

# %%
c["bl531"].build_metadata_patches(access_tags=["bl531", "bl531:beamline", "bl531:beamline:metadata"])
# Out:
# ([],
#  None,
#  [{'op': 'add',
#    'path': '/tags',
#    'value': ['bl531', 'bl531:beamline', 'bl531:beamline:metadata']}])

# %%
c["bl531"].update_metadata(access_tags=["bl531"])
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/dev/splash_tiled/.pixi/envs/tiled/lib/python3.13/site-packages/tiled/client/utils.py:86, in handle_error(response)
#      85 try:
# ---> 86     raise_for_status(response)
#      87 except httpx.RequestError:
#
# File ~/dev/splash_tiled/.pixi/envs/tiled/lib/python3.13/site-packages/tiled/client/utils.py:79, in raise_for_status(response)
#      76 message = message.format(
#      77     response, error_type=error_type, correlation_id=correlation_id
#      78 )
# ---> 79 raise httpx.HTTPStatusError(message, request=request, response=response)
#
# HTTPStatusError: Client error '403 Forbidden' for url 'https://tiled.computing.als.lbl.gov/api/v1/metadata/bl531'
# For more information, server admin can search server logs for correlation ID 949ec6201ee05119.
#
# The above exception was the direct cause of the following exception:
# ...
